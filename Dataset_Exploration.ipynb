# %% [markdown]
# <a href="https://colab.research.google.com/github/Amani-K-code/SemProject_MLEngine/blob/main/Dataset_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STEP 1 - IMPORTS

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_main = pd.read_csv("/content/drive/MyDrive/KENYA-FOOD-COMPOSITION-TABLES-2018/df_main_clean_extract.csv")

# %% [markdown]
# # Question 3:
#
# ## a. Displaying rows and columns in the dataset

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Code             139 non-null    int64
#  1   Food Name        139 non-null    object
#  2   Energy_(kJ)      139 non-null    int64
#  3   Energy_(kcal)    139 non-null    int64
#  4   Water (g)        139 non-null    float64
#  5   Protein (g)      139 non-null    float64
#  6   Fat (g)          139 non-null    float64
#  7   Carb (g)         139 non-null    float64
#  8   Fibre (g)        139 non-null    float64
#  9   Ash (g)          139 non-null    float64
#  10  Calcium (mg)     139 non-null    float64
#  11  Iron (mg)        139 non-null    float64
#  12  Magnesium (mg)   139 non-null    int64
#  13  Phosphorus (mg)  139 non-null    int64
#  14  Potassium (mg)   139 non-null    int64
#  15  Sodium (mg)      139 non-null    float64
# ...

# %%
df_main.shape
# Should display 139 rows and 29 columns
# Out:
# (139, 29)

# %% [markdown]
# ## b. Datatypes contained in the dataset

# %%
df_main.dtypes
# This should display three (int, object and float)
# Out:
# Code                 int64
# Food Name           object
# Energy_(kJ)          int64
# Energy_(kcal)        int64
# Water (g)          float64
# Protein (g)        float64
# Fat (g)            float64
# Carb (g)           float64
# Fibre (g)          float64
# Ash (g)            float64
# Calcium (mg)       float64
# Iron (mg)          float64
# Magnesium (mg)       int64
# Phosphorus (mg)      int64
# Potassium (mg)       int64
# Sodium (mg)        float64
# Zinc (mg)          float64
# Selenium (mcg)     float64
# VitA_RAE           float64
# VitA_RE            float64
# Retinol            float64
# BetaCaratone       float64
# Thiamin            float64
# Riboflavin         float64
# Niacin             float64
# DietaryFolatEq     float64
# FoodFolate         float64
# VitB12             float64
# VitC               float64
# dtype: object

# %%
df_main.describe()
# Out:
#                Code  Energy_(kJ)  Energy_(kcal)   Water (g)  Protein (g)  \
# count    139.000000   139.000000     139.000000  139.000000   139.000000
# mean   15071.561151   737.143885     176.064748   62.815108     6.853957
# std       40.962180   511.162621     122.744651   20.831233     7.831211
# min    15001.000000   121.000000      28.000000    6.800000     0.100000
# 25%    15036.500000   392.000000      93.500000   55.800000     2.500000
# 50%    15072.000000   568.000000     136.000000   68.200000     4.300000
# 75%    15106.500000   821.000000     195.000000   77.900000     7.400000
# max    15142.000000  2270.000000     549.000000   92.600000    45.700000
#
#           Fat (g)    Carb (g)   Fibre (g)     Ash (g)  Calcium (mg)  ...  \
# count  139.000000  139.000000  139.000000  139.000000    139.000000  ...
# mean     8.050360   17.583453    2.976978    1.737410     59.153237  ...
# std      9.442798   12.821848    2.384926    0.987918     91.651760  ...
# ...

# %% [markdown]
# ## c. Checking whether the dataset is complete and whether missing values are present?

# %%
df_main.isnull()
# It is not complete due to some missing values in some of the cells
# Out:
#       Code  Food Name  Energy_(kJ)  Energy_(kcal)  Water (g)  Protein (g)  \
# 0    False      False        False          False      False        False
# 1    False      False        False          False      False        False
# 2    False      False        False          False      False        False
# 3    False      False        False          False      False        False
# 4    False      False        False          False      False        False
# ..     ...        ...          ...            ...        ...          ...
# 134  False      False        False          False      False        False
# 135  False      False        False          False      False        False
# 136  False      False        False          False      False        False
# 137  False      False        False          False      False        False
# 138  False      False        False          False      False        False
#
#      Fat (g)  Carb (g)  Fibre (g)  Ash (g)  ...  VitA_RE  Retinol  \
# ...

# %%
df_main.isna().any()
# Out:
# Code               False
# Food Name          False
# Energy_(kJ)        False
# Energy_(kcal)      False
# Water (g)          False
# Protein (g)        False
# Fat (g)            False
# Carb (g)           False
# Fibre (g)          False
# Ash (g)            False
# Calcium (mg)       False
# Iron (mg)          False
# Magnesium (mg)     False
# Phosphorus (mg)    False
# Potassium (mg)     False
# Sodium (mg)        False
# Zinc (mg)          False
# Selenium (mcg)      True
# VitA_RAE            True
# VitA_RE             True
# Retinol            False
# BetaCaratone        True
# Thiamin             True
# Riboflavin          True
# Niacin              True
# DietaryFolatEq      True
# FoodFolate          True
# VitB12              True
# VitC                True
# dtype: bool

# %%
df_main.isna().sum()
# Out:
# Code                0
# Food Name           0
# Energy_(kJ)         0
# Energy_(kcal)       0
# Water (g)           0
# Protein (g)         0
# Fat (g)             0
# Carb (g)            0
# Fibre (g)           0
# Ash (g)             0
# Calcium (mg)        0
# Iron (mg)           0
# Magnesium (mg)      0
# Phosphorus (mg)     0
# Potassium (mg)      0
# Sodium (mg)         0
# Zinc (mg)           0
# Selenium (mcg)      1
# VitA_RAE            3
# VitA_RE             3
# Retinol             0
# BetaCaratone        3
# Thiamin             1
# Riboflavin          1
# Niacin              2
# DietaryFolatEq     18
# FoodFolate          4
# VitB12              4
# VitC               16
# dtype: int64

# %% [markdown]
# ## d. Slicing out first 15 rows and last 20 rows and merging them

# %%
df_sample = pd.concat([df_main.head(15), df_main.tail(20)])
df_sample
# Out:
#       Code                                          Food Name  Energy_(kJ)  \
# 0    15001                    Uji wa mahindi (Maize Porridge)          221
# 1    15002          Sorghum, Finger Millet and Maize Porridge          174
# 2    15003                          Kaimati (Fried Dumplings)         1800
# 3    15004                        Mahamri (Swahili Doughnuts)         1730
# 4    15005                            Whole Maize Flour Ugali          596
# 5    15006                Maize and Finger Millet Flour Ugali          562
# 6    15007         Maize, Red Sorghum and Finger Millet Ugali          543
# 7    15008                      Cassava and Red Sorghum Ugali          489
# 8    15009                          Refined Maize Flour Ugali          626
# 9    15010         Sorghum, Maize flour & Finger Millet Ugali          634
# 10   15011                                Cassava Flour Ugali          788
# ...
